# %% [markdown]
# # Analyze Taylor Swift Lyrics with Python
#
# ### Try some of these resources for extra help as you work:
#
# * [View the Analyze Taylor Swift Lyrics with Python Cheatsheet](https://www.codecademy.com/learn/case-study-analyze-taylor-swift-lyrics/modules/analyze-taylor-swift-lyrics/cheatsheet)
# * Learn more about analyzing text in [Apply Natural Language Processing with Python](https://www.codecademy.com/learn/paths/natural-language-processing)
#
# [View the solution notebook](./solution.html)
#
# [The original dataset was curated by Jan Llenzl Dagohoy and published on Kaggle](https://www.kaggle.com/datasets/thespacefreak/taylor-swift-song-lyrics-all-albums)

# %%
# %matplotlib inline

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import collections
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
from sklearn.feature_extraction import text
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/makariy/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### 1. Load the dataset
#
# After running the first cell to load all necessary libraries, we need to load our dataset.
# * Using pandas, load the dataset taylor_swift_lyrics_2006-2020_all.csv and save it as lyrics.
# * Inspect the first few rows.
# * Use `.info()` to determine how many rows there are, check for missing values, and check the variable types.

# %% [markdown]
# *Note that we added the lyrics from the new Midnights album. If you want to inspect the lyrics from that album, you can find them in the file tree. Click on the Jupyter logo in the upper left corner and you can see all the files.*
#
# *Use "taylor_swift_lyrics_2006-2022_all.csv" in the `pd.read_csv()` function below to also analyze Midnights.*

# %%
# load dataset
lyrics = pd.read_csv("taylor_swift_lyrics_2006-2020_all.csv")

#inspect the first few rows

lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line
# 0                    There's something 'bout the way     1
# 1             The street looks when it's just rained     2
# 2  There's a glow off the pavement, you walk me t...     3
# 3  And you know I wanna ask you to dance right there     4
# 4             In the middle of the parking lot, yeah     5

# %%
#get info about the DataFrame

lyrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8358 entries, 0 to 8357
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   album_name   8358 non-null   object
#  1   track_title  8358 non-null   object
#  2   track_n      8358 non-null   int64
#  3   lyric        8358 non-null   object
#  4   line         8358 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 326.6+ KB

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# The Taylor Swift lyrics dataset consists of comprehensive data on the lyrics from her albums 2020. There are no missing values. We can see the lyric details along the column axis and each lyric along the row axis. We can find the name  of each album, the track, and the line in which the lyric appears. We do not have year associated with this dataset.
#
# </details>

# %% [markdown]
# ### 2. Add essential data
#
# We know that we want to explore her use of terms over years, but this dataset doesn't have years. We can either merge a dataset or manually create a new column. We have created a function for you that fills in the year based on the album name.
#
# * Apply this function to the `lyrics` DataFrame to create a new column.
# * Inspect the first few rows of the DataFrame

# %%
# get a list of all the albums in this collection

lyrics.album_name.unique()
# Out:
# array(['Fearless (Taylor’s Version)', 'Red (Deluxe Edition)',
#        '1989 (Deluxe)', 'reputation', 'Taylor Swift',
#        'folklore (deluxe version)', 'Lover', 'evermore (deluxe version)',
#        'Speak Now (Deluxe)'], dtype=object)

# %%
# this is a function to map the name of the album to the year it was released
def album_release(row):  
    if row['album_name'] == 'Taylor Swift':
        return '2006'
    elif row['album_name'] == 'Fearless (Taylor’s Version)':
        return '2008'
    elif row['album_name'] == 'Speak Now (Deluxe)':
        return '2010'
    elif row['album_name'] == 'Red (Deluxe Edition)':
        return '2012'
    elif row['album_name'] == '1989 (Deluxe)':
        return '2014'
    elif row['album_name'] == 'reputation':
        return '2017'
    elif row['album_name'] == 'Lover':
        return '2019'
    elif row['album_name'] == 'evermore (deluxe version)':
        return '2020'
    #ok, we know folklore was actually released in Dec 2020, but this will make our analysis easier
    elif row['album_name'] == 'folklore (deluxe version)':
        return '2021'
    #this is slightly differently formatted because the album name is recorded two ways.
    elif 'midnights' in row['album_name']:
        return '2022'
    
    return 'No Date'


# apply the function to the album

lyrics["year"] = lyrics.apply(album_release, axis = 1)
lyrics.head() 
# inspect the first few rows of the DataFrame
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008

# %% [markdown]
# ### 3. Clean the lyric text
#
# To accurately count keyword mentions, we need to make everything lowercase everything, remove punctuation, and exclude stop words.
#
# * Change everything to lower case and save the result in a new column called `clean_lyric`.
# * Remove punctuation and save the result to the existing `clean_lyric` column.
# * Run the code we provided to remove stopwords.
# * Check to be sure you have what you expect by viewing the first few rows.

# %%
#lowercase

lyrics['clean_lyric'] = lyrics.lyric.apply(lambda lyric: lyric.lower())
lyrics.head()
#remove punctuation

punctuation = [',', "'", "!", "?", '.']

lyrics['clean_lyric'] = lyrics.clean_lyric.apply(lambda lyric: ''.join([char for char in lyric if char not in punctuation]))
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
#
#                                          clean_lyric
# 0                      theres something bout the way
# 1              the street looks when its just rained
# 2  theres a glow off the pavement you walk me to ...
# 3  and you know i wanna ask you to dance right there
# 4              in the middle of the parking lot yeah

# %%
#remove stopwords (see the next cell for illustration)
#create a small list of English stop words, feel free to edit this list
stop = ['the', 'a', 'this', 'that', 'to', 'is', 'am', 'was', 'were', 'be', 'being', 'been']


#there are three steps in one here - explained below
#we make a list of words with `.split()`
#then we remove all the words in our list
#then we join the words back together into a string
lyrics['clean_lyric'] = lyrics['clean_lyric'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
lyrics.head(10)
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 5  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 6  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 7  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 8  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 9  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
# 5                                           Oh, yeah     6  2008
# 6  We're driving down the road, I wonder if you know     7  2008
# 7        I'm trying so hard not to get caught up now     8  2008
# 8  But you're just so cool, run your hands throug...     9  2008
# 9                 Absent-mindedly making me want you    10  2008
#
#                                          clean_lyric
# 0                          theres something bout way
# 1                  street looks when its just rained
# 2           theres glow off pavement you walk me car
# 3     and you know i wanna ask you dance right there
# 4                      in middle of parking lot yeah
# 5                                            oh yeah
# 6             driving down road i wonder if you know
# 7            im trying so hard not get caught up now
# 8  but youre just so cool run your hands through ...
# 9                 absent-mindedly making me want you

# %%
# inspect the first few rows of the DataFrame

lyrics.head(10)
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 5  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 6  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 7  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 8  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 9  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
# 5                                           Oh, yeah     6  2008
# 6  We're driving down the road, I wonder if you know     7  2008
# 7        I'm trying so hard not to get caught up now     8  2008
# 8  But you're just so cool, run your hands throug...     9  2008
# 9                 Absent-mindedly making me want you    10  2008
#
#                                          clean_lyric
# 0                          theres something bout way
# 1                  street looks when its just rained
# 2           theres glow off pavement you walk me car
# 3     and you know i wanna ask you dance right there
# 4                      in middle of parking lot yeah
# 5                                            oh yeah
# 6             driving down road i wonder if you know
# 7            im trying so hard not get caught up now
# 8  but youre just so cool run your hands through ...
# 9                 absent-mindedly making me want you

# %% [markdown]
# ### The next 4 cells are for illustration only

# %%
#see what `.split()` does
lyrics['clean_lyric_list'] = lyrics['clean_lyric'].apply(lambda x: x.split())
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
#
#                                       clean_lyric  \
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah
#
#                                     clean_lyric_list
# 0                     [theres, something, bout, way]
# 1           [street, looks, when, its, just, rained]
# 2  [theres, glow, off, pavement, you, walk, me, car]
# 3  [and, you, know, i, wanna, ask, you, dance, ri...
# 4               [in, middle, of, parking, lot, yeah]

# %%
#see what `.join()` does
lyrics['clean_lyric_list_rejoined'] = lyrics['clean_lyric_list'].apply(lambda x: ' '.join(x))
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
#
#                                       clean_lyric  \
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah
#
#                                     clean_lyric_list  \
# 0                     [theres, something, bout, way]
# 1           [street, looks, when, its, just, rained]
# 2  [theres, glow, off, pavement, you, walk, me, car]
# 3  [and, you, know, i, wanna, ask, you, dance, ri...
# 4               [in, middle, of, parking, lot, yeah]
#
#                         clean_lyric_list_rejoined
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah

# %%
#remove those illustration columns
lyrics.drop(['clean_lyric_list', 'clean_lyric_list_rejoined'], axis=1, inplace=True)
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
#
#                                       clean_lyric
# 0                       theres something bout way
# 1               street looks when its just rained
# 2        theres glow off pavement you walk me car
# 3  and you know i wanna ask you dance right there
# 4                   in middle of parking lot yeah

# %%
#there are many pre-built lists of stopwords, including one from sklearn.
#Most exclude too many words to be appropriate for song lyric analysis.

skl_stop = text.ENGLISH_STOP_WORDS
print(skl_stop)
lyrics['clean_lyric'] = lyrics['clean_lyric'].apply(lambda x: ' '.join([word for word in x.split() if word not in (skl_stop)]))
lyrics.head(10)
# Out:
# frozenset({'its', 'show', 'above', 'along', 'fire', 'where', 'off', 'without', 'across', 'whom', 'whole', 'seem', 'thick', 'anywhere', 'somewhere', 'what', 'anyway', 'forty', 'former', 'moreover', 'nobody', 'same', 'them', 'fifteen', 'which', 'latter', 'whether', 'first', 'once', 'hundred', 'own', 'between', 'back', 'their', 'although', 'therefore', 'a', 'cant', 'three', 'all', 'otherwise', 'on', 'mine', 'within', 'whatever', 'take', 'everything', 'anything', 'my', 'describe', 'by', 'against', 'cannot', 'twelve', 'from', 'afterwards', 'thru', 'to', 'if', 'will', 'everyone', 'noone', 'namely', 'whereas', 'neither', 'top', 'serious', 'last', 'perhaps', 'almost', 'detail', 'hence', 'myself', 'nothing', 'up', 'couldnt', 'or', 'whenever', 'name', 'meanwhile', 'rather', 'whence', 'put', 'her', 'after', 'besides', 'among', 'thereupon', 'thus', 'something', 'wherein', 'beyond', 'beside', 'seems', 'hereupon', 'twenty', 'still', 'together', 'only', 'how', 'others', 'about', 'also', 'enough', 'someone', 'am', 'yours', 'those', 'themselves', 'few', 'throughout', 'were', 'fill', 'sometime', 'further', 'ten', 'seemed', 'and', 'now', 'since', 'becoming', 'front', 'below', 'seeming', 'whereby', 'herein', 'mostly', 'nowhere', 'un', 'no', 'this', 'yourself', 'not', 'thence', 'such', 'are', 'us', 'amongst', 'alone', 'formerly', 'bottom', 'next', 'well', 'via', 'cry', 'toward', 'your', 'mill', 'never', 'may', 'interest', 'under', 'always', 'part', 'found', 'they', 'whereafter', 'do', 'hereby', 'except', 'again', 'due', 'have', 'see', 'became', 'call', 'one', 'else', 'while', 'several', 'was', 'less', 'more', 'hasnt', 'much', 'most', 'though', 'when', 'yourselves', 'full', 'him', 'being', 'thereby', 'please', 'nor', 'become', 'anyone', 'everywhere', 'we', 'whose', 'done', 'find', 'other', 'upon', 'co', 'there', 'nine', 'over', 'itself', 'eleven', 'any', 'both', 'six', 'before', 'he', 'could', 'so', 'herself', 'down', 'might', 'yet', 'around', 'bill', 're', 'must', 'two', 'sixty', 'amount', 'already', 'in', 'at', 'system', 'for', 'either', 'who', 'but', 'go', 'too', 'four', 'out', 'it', 'de', 'somehow', 'some', 'these', 'therein', 'eg', 'ie', 'keep', 'latterly', 'ours', 'five', 'should', 'least', 'per', 'onto', 'would', 'here', 'then', 'ourselves', 'thereafter', 'thin', 'behind', 'into', 'the', 'through', 'however', 'sometimes', 'made', 'fifty', 'even', 'another', 'been', 'can', 'each', 'very', 'because', 'sincere', 'third', 'con', 'give', 'none', 'until', 'nevertheless', 'than', 'an', 'eight', 'whoever', 'inc', 'often', 'get', 'beforehand', 'i', 'you', 'as', 'me', 'towards', 'side', 'hereafter', 'ltd', 'wherever', 'etc', 'indeed', 'that', 'every', 'our', 'of', 'be', 'hers', 'elsewhere', 'is', 'many', 'whereupon', 'himself', 'anyhow', 'amoungst', 'why', 'with', 'his', 'had', 'ever', 'move', 'has', 'she', 'during', 'empty', 'becomes', 'whither'})
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 5  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 6  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 7  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 8  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 9  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
# 5                                           Oh, yeah     6  2008
# 6  We're driving down the road, I wonder if you know     7  2008
# 7        I'm trying so hard not to get caught up now     8  2008
# 8  But you're just so cool, run your hands throug...     9  2008
# 9                 Absent-mindedly making me want you    10  2008
#
#                       clean_lyric
# 0                 theres bout way
# 1        street looks just rained
# 2   theres glow pavement walk car
# 3      know wanna ask dance right
# 4         middle parking lot yeah
# 5                         oh yeah
# 6        driving road wonder know
# 7           im trying hard caught
# 8  youre just cool run hands hair
# 9     absent-mindedly making want

# %% [markdown]
# ### 4. Find keyword mentions
#
# Because we are most interested in "midnight", we will first count how many times midnight occurs in Taylor Swift's lyrics.
#
# * Create a new column to indicate if a lyric has "midnight" in it.
# * Check how many times midnight occurrs

# %%
#create a new column to reflect if the lyrics contain midnight

lyrics["midnight_count"] = lyrics.clean_lyric.apply(lambda x: x.count("midnight"))
lyrics[lyrics.midnight_count>1].head()
# Out:
# Empty DataFrame
# Columns: [album_name, track_title, track_n, lyric, line, year, clean_lyric, midnight_count]
# Index: []

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Midnight is not very common -- it only appeared 9 times!
#
# </details>

# %% [markdown]
# ### 5. Expand the keyword list
#
# Midnight might not be the only way that Taylor Swift has talked about night. We need to expand our list. We've made a list of night words and day words. Feel free to add or remove words to make the list your own.
#
# * Join the lists into a regular expression string using the `.join()` function and the `|` to indicate "or"
# * Create a new column for each word category (day, night, time) that evaluates the clean lyrics for the presence of the words in your regular expression.
# * Count how many times the words appeared and print the result to the screen
# * Inspect the first few rows of the lyrics DataFrame to be sure it looks as you expect

# %%
#night, day, and other time-related words
night = ['night','midnight', 'dawn', 'dusk', 'evening', 'late', 'dark', '1am', '2am', '3am', '4am']
day = ['day', 'morning', 'light', 'sun', 'dawn', 'noon', 'golden', 'bright']
time = ['today', 'tomorrow', 'yesterday']

# %%
#create a regular expression string for each list of words

night_regular = '|'.join(night)
day_regular = '|'.join(day)
time_regular = '|'.join(time)
#create a new column for each category of words

lyrics["night_reg"] = lyrics.clean_lyric.apply(lambda x : len(re.findall(night_regular, x)))
lyrics["day_reg"] = lyrics.clean_lyric.apply(lambda x : len(re.findall(day_regular, x)))
lyrics["time_reg"] = lyrics.clean_lyric.apply(lambda x : len(re.findall(time_regular, x)))

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Taylor Swift has referenced time alot, there's enough mentions for us to potentially spot some trends. Also, she has mentioned day far more than night. This might be because of the search terms, so we might consider revisiting the list. Or it could be because she is actually more focused on day and light than she is on night and dark.
#
# </details>

# %% [markdown]
# # Task Group 2

# %% [markdown]
# ### 6. Visualize how Taylor Swift's mentions of time have changed over time.
#
# Now that we know that she has referenced time, we can see if that has changed, and if she has been dropping any hints about her upcoming album.
# * Create a new dataframe called `yearly_mentions` that groups her mentions by year, and takes the sum of the other columns. Reset the index on this DataFrame to make it easier to use with matplotlib
# * Create a line chart in matplotlib showing the night mentions over time.

# %%
#create a new dataframe for yearly mentions that groups mentions by year

yearly_mentions = lyrics.groupby('year').sum()
yearly_mentions['year'] = yearly_mentions.index
yearly_mentions.reset_index(drop=True, inplace=True)
yearly_mentions.head()
# Out:
#                                           album_name  \
# 0  Taylor SwiftTaylor SwiftTaylor SwiftTaylor Swi...
# 1  Fearless (Taylor’s Version)Fearless (Taylor’s ...
# 2  Speak Now (Deluxe)Speak Now (Deluxe)Speak Now ...
# 3  Red (Deluxe Edition)Red (Deluxe Edition)Red (D...
# 4  1989 (Deluxe)1989 (Deluxe)1989 (Deluxe)1989 (D...
#
#                                          track_title  track_n  \
# 0  Tim McGrawTim McGrawTim McGrawTim McGrawTim Mc...     4867
# 1  Fearless (Taylor’s Version)Fearless (Taylor’s ...    15644
# 2  MineMineMineMineMineMineMineMineMineMineMineMi...     8450
# 3  State of GraceState of GraceState of GraceStat...    11992
# 4  Welcome to New YorkWelcome to New YorkWelcome ...     8424
#
#                                                lyric   line  \
# 0  He said the way my blue eyes shinedPut those G...  13456
# 1  There's something 'bout the wayThe street look...  27793
# 2  You were in college, working part-time, waitin...  27489
# 3  I'm walking fast through the traffic lightsBus...  27800
# 4  Walking through a crowd, the village is aglowK...  33546
#
#                                          clean_lyric  midnight_count  \
# 0  said way blue eyes shinedgeorgia stars shame n...               0
# 1  theres bout waystreet looks just rainedtheres ...               0
# 2  college working part-time waiting tablesleft s...               0
# 3  im walking fast traffic lightsbusy streets bus...               1
# 4  walking crowd village aglowkaleidoscope loud h...               2
#
#    night_reg  day_reg  time_reg  year
# 0         19       28         3  2006
# 1         42       72        20  2008
# 2         31       60         4  2010
# 3         51       63         7  2012
# 4         27       58         0  2014

# %%
#plot the mentions of night over years

plt.plot(yearly_mentions.year, yearly_mentions.night_reg)
plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# It looks like there was a peak in her mentioning night around 2012. It seems like those mentions have become less prevalent over time, with an actual dip in 2019! We had expected midnight to appear more often around then, based on rumors that she plans everything 3 years out.
#
# </details>

# %% [markdown]
# ### 7. What albums are the most night/day focused?
# Now that we have a table of counts, it's very easy to figure out which albums have the most mentions of day or night. But our DataFrame only has the years, not the album names. We need to add those back in.
# * Run the code that reinstates the album name for this dataframe.
# * Use `.sort_values()` to order the yearly_mentions table and find which year has the most mentions of night.
# * Sort the day column as well.

# %%
#reinstate the album name
#read the album_year_name.csv
year_name = pd.read_csv('album_year_name.csv')

#sort both dataframes by year
yearly_mentions.sort_values(by='year', ascending=True, inplace=True)
year_name.sort_values(by='album_year', ascending=True, inplace=True)

#add the new column for album name
yearly_mentions['album_name'] = year_name['album_name']

# %%
#sort the lyrics by the night column to find the albums with the most night references

yearly_mentions.sort_values(by='night_reg', ascending = False, inplace=True)
yearly_mentions.head()
# Out:
#                   album_name  \
# 3                 reputation
# 1       Red (Deluxe Edition)
# 2              1989 (Deluxe)
# 5  folklore (deluxe version)
# 4               Taylor Swift
#
#                                          track_title  track_n  \
# 3  State of GraceState of GraceState of GraceStat...    11992
# 1  Fearless (Taylor’s Version)Fearless (Taylor’s ...    15644
# 2  MineMineMineMineMineMineMineMineMineMineMineMi...     8450
# 5  ...Ready for It?...Ready for It?...Ready for I...     7640
# 4  Welcome to New YorkWelcome to New YorkWelcome ...     8424
#
#                                                lyric   line  \
# 3  I'm walking fast through the traffic lightsBus...  27800
# 1  There's something 'bout the wayThe street look...  27793
# 2  You were in college, working part-time, waitin...  27489
# 5  Knew he was a killer first time that I saw him...  33775
# 4  Walking through a crowd, the village is aglowK...  33546
#
#                                          clean_lyric  midnight_count  \
# 3  im walking fast traffic lightsbusy streets bus...               1
# 1  theres bout waystreet looks just rainedtheres ...               0
# 2  college working part-time waiting tablesleft s...               0
# 5  knew killer time sawwondered girls loved left ...               3
# 4  walking crowd village aglowkaleidoscope loud h...               2
#
#    night_reg  day_reg  time_reg  year
# 3         51       63         7  2012
# 1         42       72        20  2008
# 2         31       60         4  2010
# 5         30       35         0  2017
# 4         27       58         0  2014

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Her most "nightly" album was reputation in 2012, whereas her least nightly album was also the one right before Midnight. Has she been saving all her night-related lyrics for the past 3 years?
#
# </details>

# %%
#sort the lyrics by the day column to find the albums with the most day references

yearly_mentions.sort_values(by='day_reg', ascending = False, inplace=True)
yearly_mentions.head()
# Out:
#              album_name                                        track_title  \
# 6                 Lover  I Forgot That You ExistedI Forgot That You Exi...
# 1  Red (Deluxe Edition)  Fearless (Taylor’s Version)Fearless (Taylor’s ...
# 3            reputation  State of GraceState of GraceState of GraceStat...
# 2         1989 (Deluxe)  MineMineMineMineMineMineMineMineMineMineMineMi...
# 4          Taylor Swift  Welcome to New YorkWelcome to New YorkWelcome ...
#
#    track_n                                              lyric   line  \
# 6     8813  How many days did I spend thinking'Bout how yo...  25741
# 1    15644  There's something 'bout the wayThe street look...  27793
# 3    11992  I'm walking fast through the traffic lightsBus...  27800
# 2     8450  You were in college, working part-time, waitin...  27489
# 4     8424  Walking through a crowd, the village is aglowK...  33546
#
#                                          clean_lyric  midnight_count  \
# 6  days did spend thinkingbout did wrong wrong wr...               0
# 1  theres bout waystreet looks just rainedtheres ...               0
# 3  im walking fast traffic lightsbusy streets bus...               1
# 2  college working part-time waiting tablesleft s...               0
# 4  walking crowd village aglowkaleidoscope loud h...               2
#
#    night_reg  day_reg  time_reg  year
# 6         26      115         0  2019
# 1         42       72        20  2008
# 3         51       63         7  2012
# 2         31       60         4  2010
# 4         27       58         0  2014

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# It seems like her older work focused on day much more than her more recent. There was a period of time (2008-2012) when she was really focused on day, but it seems to have become less central to her work more recently.
#
# </details>

# %% [markdown]
# ### 8. Compare day to night mentions
# * Create another line chart with both the night mentions and the day mentions

# %%
#create a plot with one line showing number of night references by year 
#and another line with the number of day references by year

yearly_mentions.sort_values(by="year", inplace= True)
plt.plot(yearly_mentions.year,yearly_mentions.night_reg, label="Night")
plt.plot(yearly_mentions.year,yearly_mentions.day_reg, label="Day")

plt.legend()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# Well this is interesting. We see a similar dip in referencing time around 2017, but a sharp increase in both 2019 and 2020 to reference day.
#
# </details>

# %% [markdown]
# ### 9. Investigate position of day vs. night mentions within albums
# Maybe her references to time aren't always about the year that she released the album, but the ebb and flow of the album itself. Let's plot where, within each album, references to day and night occur.
#
# * Create a variable that indicates the position of a lyric within an album. Call this 'position'.
# * Create a new dataframe called positional_mentions that groups her mentions by album position, and takes the sum of the other columns. Reset the index on this DataFrame to make it easier to use with matplotlib.
# * Create a line chart in matplotlib showing the night and day mentions as a position within the album.
#
# *Remember that you can always print the head of the DataFrame to check your work*

# %%
#create a position variable that includes both the track number and line number
lyrics["position"] = lyrics.apply(lambda x: f"{x.track_n},{x.line}", axis=1)

#create a new DataFrame that is grouped by position
lyrics_positions = lyrics.loc[:,['night_reg', 'day_reg', 'position']].groupby("position").sum()
lyrics_positions.head()
# Out:
#           night_reg  day_reg
# position
# 1,1               1        2
# 1,10              0        0
# 1,11              1        3
# 1,12              0        1
# 1,13              1        0

# %%
#increase the size of the plot 
fig = plt.gcf()
fig.set_size_inches(25,10)

#create a plot with two lines to show frequency of day vs. night references by position in the album
plt.plot(lyrics_positions.index, lyrics_positions.night_reg, label ="night")
plt.plot(lyrics_positions.index, lyrics_positions.day_reg, label ="day")
plt.legend()
plt.show()

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#     Honestly not that much -- we can't see any strong trends here. Best to move on.
# </details>

# %% [markdown]
# # Task Group 3

# %% [markdown]
# ### 10. Tokenize the Lyrics
# It's great to know how much she has focused on day and night, but we would also like to do a little more sophisticated analysis. Before we can work with our cleaned lyrics, we will have to tokenize them. Tokenization is a special way of breaking up words that is a little more nuanced than just using white space. The output is a list of words that we can then perform text analysis on.
#
# We will use the `word_tokenize` function from NLTK (the Natural Language ToolKit), and apply it to every row in our DataFrame with a lambda expression.
#
# * Run the cell to tokenize the cleaned lyrics.
# * Inspect the first few rows of the lyrics DataFrame
# * Create a list of all the tokens in the lyrics_tok column into one list
# * Use the Counter function from the collections package to count the number of times each word appears
# * Sort the resulting dictionary

# %%
#run this cell to tokenize the words in the clean_lyric column
lyrics['lyrics_tok'] = lyrics['clean_lyric'].apply(word_tokenize)


lyrics.head(100)
# Out:
#                      album_name                    track_title  track_n  \
# 0   Fearless (Taylor’s Version)    Fearless (Taylor’s Version)        1
# 1   Fearless (Taylor’s Version)    Fearless (Taylor’s Version)        1
# 2   Fearless (Taylor’s Version)    Fearless (Taylor’s Version)        1
# 3   Fearless (Taylor’s Version)    Fearless (Taylor’s Version)        1
# 4   Fearless (Taylor’s Version)    Fearless (Taylor’s Version)        1
# ..                          ...                            ...      ...
# 95  Fearless (Taylor’s Version)  Love Story (Taylor’s Version)        3
# 96  Fearless (Taylor’s Version)  Love Story (Taylor’s Version)        3
# 97  Fearless (Taylor’s Version)  Love Story (Taylor’s Version)        3
# 98  Fearless (Taylor’s Version)  Love Story (Taylor’s Version)        3
# 99  Fearless (Taylor’s Version)  Love Story (Taylor’s Version)        3
#
#                                                 lyric  line  year  \
# 0                     There's something 'bout the way     1  2008
# 1              The street looks when it's just rained     2  2008
# 2   There's a glow off the pavement, you walk me t...     3  2008
# 3   And you know I wanna ask you to dance right there     4  2008
# 4              In the middle of the parking lot, yeah     5  2008
# ..                                                ...   ...   ...
# 95                                   And say, "Hello"     7  2008
# 96                                  Little did I know     8  2008
# 97     That you were Romeo, you were throwing pebbles     9  2008
# 98         And my daddy said, "Stay away from Juliet"    10  2008
# 99                  And I was crying on the staircase    11  2008
#
#                       clean_lyric  midnight_count  night_reg  day_reg  \
# 0                 theres bout way               0          0        0
# 1        street looks just rained               0          0        0
# 2   theres glow pavement walk car               0          0        0
# 3      know wanna ask dance right               0          0        0
# 4         middle parking lot yeah               0          0        0
# ..                            ...             ...        ...      ...
# 95                    say "hello"               0          0        0
# 96                little did know               0          0        0
# 97         romeo throwing pebbles               0          0        0
# 98  daddy said "stay away juliet"               0          0        0
# 99               crying staircase               0          0        0
#
#     time_reg                                 lyrics_tok  \
# 0          0                        [theres, bout, way]
# 1          0              [street, looks, just, rained]
# 2          0        [theres, glow, pavement, walk, car]
# 3          0         [know, wan, na, ask, dance, right]
# 4          0               [middle, parking, lot, yeah]
# ..       ...                                        ...
# 95         0                       [say, ``, hello, '']
# 96         0                        [little, did, know]
# 97         0                 [romeo, throwing, pebbles]
# 98         0  [daddy, said, ``, stay, away, juliet, '']
# 99         0                        [crying, staircase]
#
#                                              polarity    neg    neu    pos  \
# 0   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 1   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 2   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 3   {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 4   {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...  0.000  0.577  0.423
# ..                                                ...    ...    ...    ...
# 95  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 96  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 97  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 98  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...  0.000  1.000  0.000
# 99  {'neg': 0.756, 'neu': 0.244, 'pos': 0.0, 'comp...  0.756  0.244  0.000
#
#     compound position
# 0     0.0000      1,1
# 1     0.0000      1,2
# 2     0.0000      1,3
# 3     0.0000      1,4
# 4     0.2960      1,5
# ..       ...      ...
# 95    0.0000      3,7
# 96    0.0000      3,8
# 97    0.0000      3,9
# 98    0.0000     3,10
# 99   -0.4767     3,11
#
# [100 rows x 18 columns]

# %%
#determine what words overall are the most frequently used words
#create a list of all the words in the lyrics_tok column
word_list = [word for list_ in lyrics['lyrics_tok'] for word in list_]

#use the counter function to count the number of times each word appears

count_word = collections.Counter(word_list)

#sort the word frequencies to find out the most common words she's used. 

sorted_dict = dict(sorted(count_word.items(), key=lambda item: item[1], reverse=True))

sorted_dict
#call the word frequency

frequence = {key: value/len(word_list)*100 for key, value in sorted_dict.items()}
frequence
# Out:
# {'(': 2.286327003562658,
#  ')': 2.286327003562658,
#  'im': 1.7156099754418734,
#  'like': 1.687938846805714,
#  'know': 1.5772543322610773,
#  'oh': 1.4216042336826813,
#  'dont': 1.352426412092283,
#  'just': 1.172564075957248,
#  'youre': 1.0930095811282903,
#  'love': 1.0203728684583722,
#  'na': 0.9546539379474941,
#  'time': 0.9027705717546954,
#  'cause': 0.8750994431185362,
#  '``': 0.7817093839714987,
#  "''": 0.7782504928919788,
#  'got': 0.7644149285738991,
#  'say': 0.6848604337449413,
#  'think': 0.664107087267822,
#  'baby': 0.6502715229497423,
#  'want': 0.626059285393103,
#  'come': 0.5949292656774239,
#  'wan': 0.5568814638027049,
#  'right': 0.5361281173255854,
#  'said': 0.5049980976099062,
#  'yeah': 0.5015392065303863,
#  'ill': 0.48770364221230667,
#  'look': 0.4600325135761475,
#  'thats': 0.4600325135761475,
#  'stay': 0.4219847117014285,
#  '’': 0.41506692954238866,
#  'way': 0.40469025630382904,
#  'ive': 0.40123136522430913,
#  'tell': 0.3977724741447892,
#  'night': 0.3943135830652693,
#  'id': 0.39085469198574935,
#  'gon': 0.39085469198574935,
#  'home': 0.3804780187471896,
#  'did': 0.3528068901110304,
#  'good': 0.3528068901110304,
#  'ooh': 0.3493479990315105,
#  'oh-oh': 0.3355124347134309,
#  'feel': 0.332053543633911,
#  'bad': 0.32167687039535126,
#  'better': 0.3113001971567915,
#  'things': 0.3113001971567915,
#  'away': 0.3043824149977517,
#  'didnt': 0.30092352391823185,
#  'you': 0.29400574175919203,
#  'wish': 0.2905468506796721,
#  'girl': 0.2905468506796721,
#  'new': 0.28708795960015215,
#  'eyes': 0.28362906852063224,
#  'i': 0.28362906852063224,
#  'shake': 0.2801701774411124,
#  'let': 0.2801701774411124,
#  'long': 0.2801701774411124,
#  'knew': 0.27325239528207257,
#  'red': 0.2628757220435129,
#  'ah': 0.259416830963993,
#  'eh': 0.2524990488049531,
#  'youll': 0.24558126664591332,
#  'little': 0.24212237556639343,
#  'make': 0.24212237556639343,
#  'thing': 0.24212237556639343,
#  'forever': 0.2317457023278337,
#  'hes': 0.22482792016879385,
#  'life': 0.221369029089274,
#  'hey': 0.221369029089274,
#  'best': 0.2179101380097541,
#  'break': 0.21445124693023418,
#  'face': 0.21099235585071424,
#  'leave': 0.21099235585071424,
#  'heart': 0.21099235585071424,
#  'day': 0.20753346477119433,
#  'lights': 0.20753346477119433,
#  'mind': 0.20061568261215457,
#  'gone': 0.20061568261215457,
#  'need': 0.19715679153263466,
#  'remember': 0.19369790045311472,
#  'waiting': 0.1902390093735948,
#  'smile': 0.18678011829407493,
#  'man': 0.18678011829407493,
#  'theres': 0.1798623361350351,
#  'thought': 0.1798623361350351,
#  'beautiful': 0.1798623361350351,
#  'car': 0.1764034450555152,
#  'isnt': 0.1764034450555152,
#  'dancing': 0.1764034450555152,
#  'knows': 0.17294455397599529,
#  'whoa': 0.1694856628964754,
#  'hands': 0.1660267718169555,
#  'friends': 0.1660267718169555,
#  'aint': 0.1660267718169555,
#  'hope': 0.1660267718169555,
#  'mad': 0.1660267718169555,
#  'wont': 0.16256788073743558,
#  'hold': 0.16256788073743558,
#  'head': 0.15910898965791567,
#  'walk': 0.15565009857839576,
#  'fall': 0.15565009857839576,
#  'lost': 0.15565009857839576,
#  'shes': 0.15565009857839576,
#  'door': 0.15565009857839576,
#  'end': 0.15565009857839576,
#  'wrong': 0.15565009857839576,
#  'run': 0.15219120749887585,
#  'hand': 0.15219120749887585,
#  'coming': 0.15219120749887585,
#  'feeling': 0.15219120749887585,
#  'mean': 0.15219120749887585,
#  'hate': 0.15219120749887585,
#  'left': 0.14873231641935597,
#  'sorry': 0.14527342533983606,
#  'clear': 0.14527342533983606,
#  'light': 0.14181453426031612,
#  'miss': 0.14181453426031612,
#  'place': 0.14181453426031612,
#  'trying': 0.13835564318079624,
#  'talk': 0.13835564318079624,
#  'youve': 0.13835564318079624,
#  'old': 0.13835564318079624,
#  'daylight': 0.13835564318079624,
#  'room': 0.13489675210127633,
#  'saw': 0.13489675210127633,
#  'took': 0.13489675210127633,
#  'dress': 0.13143786102175645,
#  'dreams': 0.13143786102175645,
#  'hear': 0.13143786102175645,
#  'watch': 0.13143786102175645,
#  'follow': 0.13143786102175645,
#  'york': 0.13143786102175645,
#  'meet': 0.13143786102175645,
#  'everybody': 0.13143786102175645,
#  'woods': 0.13143786102175645,
#  'town': 0.1279789699422365,
#  'really': 0.1279789699422365,
#  'play': 0.1279789699422365,
#  'dark': 0.1279789699422365,
#  'met': 0.12452007886271661,
#  'rain': 0.12452007886271661,
#  'world': 0.12452007886271661,
#  'live': 0.12452007886271661,
#  'street': 0.12106118778319672,
#  'kiss': 0.12106118778319672,
#  'known': 0.12106118778319672,
#  'ha': 0.12106118778319672,
#  'people': 0.1176022967036768,
#  'it': 0.1176022967036768,
#  'blue': 0.1176022967036768,
#  'gave': 0.1141434056241569,
#  'forget': 0.1141434056241569,
#  'big': 0.1141434056241569,
#  'asking': 0.1141434056241569,
#  'nice': 0.1141434056241569,
#  'shouldve': 0.1141434056241569,
#  'song': 0.110684514544637,
#  'used': 0.110684514544637,
#  'welcome': 0.110684514544637,
#  'trouble': 0.110684514544637,
#  '|': 0.110684514544637,
#  'darling': 0.110684514544637,
#  'wanted': 0.10722562346511709,
#  'yes': 0.10722562346511709,
#  'fight': 0.10722562346511709,
#  'phone': 0.10722562346511709,
#  'youd': 0.10722562346511709,
#  'game': 0.10722562346511709,
#  'lose': 0.10722562346511709,
#  'loved': 0.10376673238559717,
#  'wait': 0.10376673238559717,
#  'getting': 0.10376673238559717,
#  'meaning': 0.10376673238559717,
#  'hard': 0.10030784130607728,
#  'help': 0.10030784130607728,
#  'silence': 0.10030784130607728,
#  'today': 0.10030784130607728,
#  'turn': 0.10030784130607728,
#  'touch': 0.10030784130607728,
#  're': 0.10030784130607728,
#  'official': 0.10030784130607728,
#  'lyrics': 0.10030784130607728,
#  '&': 0.10030784130607728,
#  'verified': 0.10030784130607728,
#  'late': 0.09684895022655736,
#  'heard': 0.09684895022655736,
#  'times': 0.09684895022655736,
#  'mr': 0.09684895022655736,
#  'goes': 0.09684895022655736,
#  'drive': 0.09339005914703746,
#  'believe': 0.09339005914703746,
#  'soon': 0.09339005914703746,
#  'went': 0.09339005914703746,
#  'looking': 0.09339005914703746,
#  'breathe': 0.09339005914703746,
#  'll': 0.09339005914703746,
#  'fly': 0.09339005914703746,
#  'true': 0.09339005914703746,
#  'fake': 0.09339005914703746,
#  'soul': 0.09339005914703746,
#  'body': 0.09339005914703746,
#  'til': 0.08993116806751755,
#  'try': 0.08993116806751755,
#  'standing': 0.08993116806751755,
#  'story': 0.08993116806751755,
#  'change': 0.08993116806751755,
#  'high': 0.08993116806751755,
#  'honey': 0.08993116806751755,
#  'weve': 0.08993116806751755,
#  'bye': 0.08993116806751755,
#  'joeboy': 0.08993116806751755,
#  'sip': 0.08993116806751755,
#  'alcohol': 0.08993116806751755,
#  'someday': 0.08647227698799764,
#  'dead': 0.08647227698799764,
#  'save': 0.08647227698799764,
#  'fine': 0.08647227698799764,
#  'friend': 0.08647227698799764,
#  'rains': 0.08647227698799764,
#  't': 0.08647227698799764,
#  'came': 0.08647227698799764,
#  'places': 0.08647227698799764,
#  'grow': 0.08647227698799764,
#  'seen': 0.08301338590847775,
#  'years': 0.08301338590847775,
#  'boy': 0.08301338590847775,
#  'far': 0.08301338590847775,
#  'this': 0.08301338590847775,
#  'wed': 0.08301338590847775,
#  'fun': 0.08301338590847775,
#  'dance': 0.07955449482895784,
#  'makes': 0.07955449482895784,
#  'ground': 0.07955449482895784,
#  'shine': 0.07955449482895784,
#  'happy': 0.07955449482895784,
#  'anymore': 0.07955449482895784,
#  'crazy': 0.07955449482895784,
#  'eye': 0.07955449482895784,
#  'jump': 0.07955449482895784,
#  'dream': 0.07955449482895784,
#  'alright': 0.07955449482895784,
#  'doesnt': 0.0553422572723185,
#  'says': 0.0553422572723185,
#  'line': 0.0553422572723185,
#  'beat': 0.0553422572723185,
#  'open': 0.0553422572723185,
#  'held': 0.0553422572723185,
#  'goodbye': 0.0553422572723185,
#  'wasnt': 0.0553422572723185,
#  'feels': 0.0553422572723185,
#  'free': 0.0553422572723185,
#  'reason': 0.0553422572723185,
#  'city': 0.0553422572723185,
#  'no': 0.0553422572723185,
#  'alive': 0.0553422572723185,
#  'gorgeous': 0.0553422572723185,
#  'cornelia': 0.0553422572723185,
#  'party': 0.05188336619279858,
#  'go': 0.05188336619279858,
#  'white': 0.05188336619279858,
#  'belong': 0.05188336619279858,
#  'laugh': 0.05188336619279858,
#  'favorite': 0.05188336619279858,
#  'simple': 0.05188336619279858,
#  'hurt': 0.05188336619279858,
#  'sick': 0.05188336619279858,
#  'heres': 0.05188336619279858,
#  'screaming': 0.05188336619279858,
#  'looked': 0.05188336619279858,
#  'called': 0.05188336619279858,
#  'sure': 0.05188336619279858,
#  'sun': 0.05188336619279858,
#  'tears': 0.05188336619279858,
#  'die': 0.05188336619279858,
#  'don': 0.05188336619279858,
#  'losing': 0.05188336619279858,
#  'running': 0.05188336619279858,
#  'trust': 0.05188336619279858,
#  'list': 0.05188336619279858,
#  'works': 0.05188336619279858,
#  'worse': 0.05188336619279858,
#  'fancy': 0.05188336619279858,
#  'happiness': 0.05188336619279858,
#  'plans': 0.05188336619279858,
#  'bless': 0.05188336619279858,
#  'lot': 0.04842447511327868,
#  'round': 0.04842447511327868,
#  'crying': 0.04842447511327868,
#  'comes': 0.04842447511327868,
#  'stupid': 0.04842447511327868,
#  'feet': 0.04842447511327868,
#  'doing': 0.04842447511327868,
#  'ending': 0.04842447511327868,
#  'doin': 0.04842447511327868,
#  'couldve': 0.04842447511327868,
#  'bright': 0.04842447511327868,
#  'taking': 0.04842447511327868,
#  's': 0.04842447511327868,
#  'sing': 0.04842447511327868,
#  'saying': 0.04842447511327868,
#  'whos': 0.04842447511327868,
#  'worth': 0.04842447511327868,
#  'black': 0.04842447511327868,
#  'worst': 0.04842447511327868,
#  'never': 0.04842447511327868,
#  'treacherous': 0.04842447511327868,
#  'bed': 0.04842447511327868,
#  'does': 0.04842447511327868,
#  'whats': 0.04842447511327868,
#  'memories': 0.04842447511327868,
#  'now': 0.04842447511327868,
#  'breath': 0.044965584033758776,
#  'wondering': 0.044965584033758776,
#  'wake': 0.044965584033758776,
#  'work': 0.044965584033758776,
#  'watched': 0.044965584033758776,
#  'undone': 0.044965584033758776,
#  'speak': 0.044965584033758776,
#  'school': 0.044965584033758776,
#  'we': 0.044965584033758776,
#  'outside': 0.044965584033758776,
#  'learned': 0.044965584033758776,
#  'apart': 0.044965584033758776,
#  'rest': 0.044965584033758776,
#  'pretend': 0.044965584033758776,
#  'signs': 0.044965584033758776,
#  'golden': 0.044965584033758776,
#  'moved': 0.044965584033758776,
#  'nights': 0.044965584033758776,
#  '22': 0.044965584033758776,
#  'problems': 0.044965584033758776,
#  'heels': 0.02767112863615925,
#  'playing': 0.02767112863615925,
#  'bring': 0.02767112863615925,
#  'tried': 0.02767112863615925,
#  'innocent': 0.02767112863615925,
#  'space': 0.02767112863615925,
#  'stare': 0.02767112863615925,
#  'bedroom': 0.02767112863615925,
#  'lives': 0.02767112863615925,
#  'wind': 0.02767112863615925,
#  'scream': 0.02767112863615925,
#  'guitar': 0.02767112863615925,
#  'sweet': 0.02767112863615925,
#  'telling': 0.02767112863615925,
#  'flying': 0.02767112863615925,
#  'solve': 0.02767112863615925,
#  'reckless': 0.02767112863615925,
#  'choice': 0.02767112863615925,
#  'bone': 0.02767112863615925,
#  'care': 0.02767112863615925,
#  'flew': 0.02767112863615925,
#  'hell': 0.02767112863615925,
#  'pieces': 0.02767112863615925,
#  'cheeks': 0.02767112863615925,
#  'kid': 0.02767112863615925,
#  'instead': 0.02767112863615925,
#  'sleeping': 0.02767112863615925,
#  'ooh-ooh-ooh-ooh-ooh': 0.02767112863615925,
#  'ever': 0.02767112863615925,
#  'fears': 0.02767112863615925,
#  'oh-ho': 0.02767112863615925,
#  'warm': 0.02767112863615925,
#  'train': 0.02767112863615925,
#  'queen': 0.02767112863615925,
#  'they': 0.02767112863615925,
#  'money': 0.02767112863615925,
#  'rose': 0.02767112863615925,
#  'tall': 0.02767112863615925,
#  'ones': 0.02767112863615925,
#  'great': 0.02767112863615925,
#  'keeps': 0.02767112863615925,
#  'flames': 0.02767112863615925,
#  'scar': 0.02767112863615925,
#  'king': 0.02767112863615925,
#  'leads': 0.02767112863615925,
#  'mmm-mmm': 0.02767112863615925,
#  'up': 0.02767112863615925,
#  'spot': 0.02767112863615925,
#  'ha-ah': 0.02767112863615925,
#  'strike': 0.02767112863615925,
#  'waters': 0.02767112863615925,
#  'living': 0.02767112863615925,
#  'haunt': 0.02767112863615925,
#  'film': 0.02767112863615925,
#  'kill': 0.02767112863615925,
#  'thousand': 0.02767112863615925,
#  'wreck': 0.02767112863615925,
#  'dorothea': 0.02767112863615925,
#  'driving': 0.02421223755663934,
#  'seat': 0.02421223755663934,
#  'team': 0.02421223755663934,
#  'marry': 0.02421223755663934,
#  'realized': 0.02421223755663934,
#  'prince': 0.02421223755663934,
#  'ring': 0.02421223755663934,
#  'pick': 0.02421223755663934,
#  'mmm-mm': 0.02421223755663934,
#  'rocks': 0.02421223755663934,
#  'holding': 0.02421223755663934,
#  'leaving': 0.02421223755663934,
#  'honestly': 0.02421223755663934,
#  'believed': 0.02421223755663934,
#  'shoulda': 0.02421223755663934,
#  'knees': 0.02421223755663934,
#  'forgiveness': 0.02421223755663934,
#  'shell': 0.02421223755663934,
#  'songs': 0.02421223755663934,
#  'someones': 0.02421223755663934,
#  'hoping': 0.02421223755663934,
#  'cursing': 0.02421223755663934,
#  'talks': 0.02421223755663934,
#  'tight': 0.02421223755663934,
#  'hallelujah': 0.02421223755663934,
#  'faster': 0.02421223755663934,
#  'battle': 0.02421223755663934,
#  'sound': 0.02421223755663934,
#  'spelling': 0.02421223755663934,
#  'start': 0.02421223755663934,
#  'rules': 0.02421223755663934,
#  'wall': 0.02421223755663934,
#  'counting': 0.02421223755663934,
#  'conversation': 0.02421223755663934,
#  'faded': 0.02421223755663934,
#  'stairs': 0.02421223755663934,
#  'shouldnt': 0.02421223755663934,
#  'lived': 0.02421223755663934,
#  'wasted': 0.02421223755663934,
#  'freedom': 0.02421223755663934,
#  'hows': 0.02421223755663934,
#  'shining': 0.02421223755663934,
#  'i-i-i': 0.02421223755663934,
#  'truth': 0.02421223755663934,
#  'clothes': 0.02421223755663934,
#  'skin': 0.02421223755663934,
#  'hurts': 0.02421223755663934,
#  'headlights': 0.02421223755663934,
#  'drowning': 0.02421223755663934,
#  'joke': 0.02421223755663934,
#  'ran': 0.02421223755663934,
#  'asked': 0.02421223755663934,
#  'lonely': 0.02421223755663934,
#  'what': 0.02421223755663934,
#  'wearing': 0.02421223755663934,
#  'brand': 0.02421223755663934,
#  'spend': 0.02421223755663934,
#  'lipstick': 0.02421223755663934,
#  'players': 0.02421223755663934,
#  'palm': 0.02421223755663934,
#  'whyd': 0.02421223755663934,
#  'all': 0.02421223755663934,
#  'shiny': 0.02421223755663934,
#  'get': 0.02421223755663934,
#  'whisper': 0.02421223755663934,
#  'older': 0.02421223755663934,
#  'haunted': 0.02421223755663934,
#  'my': 0.02421223755663934,
#  'lie': 0.02421223755663934,
#  'twice': 0.02421223755663934,
#  'kingdom': 0.02421223755663934,
#  'actress': 0.02421223755663934,
#  'ridin': 0.02421223755663934,
#  'dying': 0.02421223755663934,
#  'case': 0.02421223755663934,
#  'pay': 0.02421223755663934,
#  'dear': 0.02421223755663934,
#  'roll': 0.02421223755663934,
#  'glass': 0.02421223755663934,
#  'huh': 0.02421223755663934,
#  'me-e-e': 0.02421223755663934,
#  'colder': 0.02421223755663934,
#  'superman': 0.02421223755663934,
#  'nothin': 0.020753346477119437,
#  'la-la-la': 0.020753346477119437,
#  'crowd': 0.020753346477119437,
#  'romeo': 0.020753346477119437,
#  'near': 0.020753346477119437,
#  'reasons': 0.020753346477119437,
#  'forth': 0.020753346477119437,
#  'itll': 0.020753346477119437,
#  'secrets': 0.020753346477119437,
#  '2am': 0.020753346477119437,
#  'happened': 0.020753346477119437,
#  'second': 0.020753346477119437,
#  'trees': 0.020753346477119437,
#  'names': 0.020753346477119437,
#  'ride': 0.020753346477119437,
#  'smiles': 0.020753346477119437,
#  'wide': 0.020753346477119437,
#  'brighter': 0.020753346477119437,
#  'dim': 0.020753346477119437,
#  'radio': 0.020753346477119437,
#  'comin': 0.020753346477119437,
#  'starin': 0.020753346477119437,
#  'lies': 0.020753346477119437,
#  'casually': 0.020753346477119437,
#  'different': 0.020753346477119437,
#  'when': 0.020753346477119437,
#  'gate': 0.020753346477119437,
#  'saint': 0.020753346477119437,
#  'so': 0.020753346477119437,
#  'colors': 0.020753346477119437,
#  'forgetting': 0.020753346477119437,
#  'impossible': 0.020753346477119437,
#  'midnight': 0.020753346477119437,
#  'given': 0.020753346477119437,
#  'revenge': 0.01729445539759953,
#  'rainy': 0.01729445539759953,
#  'corner': 0.01729445539759953,
#  'matter': 0.01729445539759953,
#  'assume': 0.01729445539759953,
#  'ruining': 0.01729445539759953,
#  'tea': 0.01729445539759953,
#  'twisted': 0.01729445539759953,
#  'dinner': 0.01729445539759953,
#  'betty': 0.01729445539759953,
#  'sidewalk': 0.01729445539759953,
#  'skipping': 0.01729445539759953,
#  'church': 0.01729445539759953,
#  'ache': 0.01729445539759953,
#  'tolerate': 0.01729445539759953,
#  'lettin': 0.01729445539759953,
#  'fits': 0.01729445539759953,
#  'breaks': 0.01729445539759953,
#  'forward': 0.01729445539759953,
#  'catching': 0.01729445539759953,
#  'weather': 0.01729445539759953,
#  'careless': 0.01729445539759953,
#  'mans': 0.01729445539759953,
#  'careful': 0.01729445539759953,
#  'vow': 0.01729445539759953,
#  'messed': 0.01729445539759953,
#  'wonderstruck': 0.01729445539759953,
#  'pretenders': 0.01729445539759953,
#  'pull': 0.013835564318079625,
#  'tells': 0.013835564318079625,
#  'figure': 0.013835564318079625,
#  'date': 0.013835564318079625,
#  'flyin': 0.013835564318079625,
#  'mamas': 0.013835564318079625,
#  'pebbles': 0.013835564318079625,
#  'arent': 0.013835564318079625,
#  'horse': 0.013835564318079625,
#  'mistake': 0.013835564318079625,
#  'mirror': 0.013835564318079625,
#  'park': 0.013835564318079625,
#  'cover': 0.013835564318079625,
#  'ruin': 0.013835564318079625,
#  'confused': 0.013835564318079625,
#  'push': 0.013835564318079625,
#  'kissing': 0.013835564318079625,
#  'minute': 0.013835564318079625,
#  'coat': 0.013835564318079625,
#  'patch': 0.013835564318079625,
#  'stronger': 0.013835564318079625,
#  'brother': 0.013835564318079625,
#  'kitchen': 0.013835564318079625,
#  'age': 0.013835564318079625,
#  'seven': 0.013835564318079625,
#  'history': 0.013835564318079625,
#  'thе': 0.013835564318079625,
#  'notice': 0.013835564318079625,
#  'falls': 0.013835564318079625,
#  ...}

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    She mostly talks about you and then herself, while that's not surprising, it also tells us that she's mostly writing about relationships and her realtionships with others.
# </details>

# %% [markdown]
# ### 11. Analyze Lyric Sentiment
#
# To better understand how she thinks and feels about day and night, we want to know which one she writes about more favorably.
#
# We are going to use the pre-trained sentiment classifier that comes with NLTK. It's it trained on tweets and therefore best for short text. It return 4 values: positive, negative, neutral, and compound. Compound will be of special interest to us. It is the normalized sum of positive and negative.
#
# * Run the sample sentiment analyzer cell to see how the SentimentIntensityAnalyzer works.
# * Apply the sia sentiment analyzer to the clean_lyric column of the DataFrame with a lambda expression
# * Run the cell that transforms the dictionary into columns of the DataFrame

# %%
#run this cell to add a package from NLTK for our sentiment analyzer.
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/makariy/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
#run this cell to see how the sentiment analyzer works
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("I love Taylor Swift!")
# Out:
# {'neg': 0.0, 'neu': 0.137, 'pos': 0.863, 'compound': 0.7424}

# %%
#create a new column called polarity and apply the sia method to the clean_lyric column with a lambda expression

lyrics['polarity'] = lyrics.clean_lyric.apply(sia.polarity_scores)
lyrics.head()
# Out:
#                     album_name                  track_title  track_n  \
# 0  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4  Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
#
#                                                lyric  line  year  \
# 0                    There's something 'bout the way     1  2008
# 1             The street looks when it's just rained     2  2008
# 2  There's a glow off the pavement, you walk me t...     3  2008
# 3  And you know I wanna ask you to dance right there     4  2008
# 4             In the middle of the parking lot, yeah     5  2008
#
#                      clean_lyric  midnight_count  night_reg  day_reg  \
# 0                theres bout way               0          0        0
# 1       street looks just rained               0          0        0
# 2  theres glow pavement walk car               0          0        0
# 3     know wanna ask dance right               0          0        0
# 4        middle parking lot yeah               0          0        0
#
#    time_reg                           lyrics_tok  \
# 0         0                  [theres, bout, way]
# 1         0        [street, looks, just, rained]
# 2         0  [theres, glow, pavement, walk, car]
# 3         0     [know, wanna, ask, dance, right]
# 4         0         [middle, parking, lot, yeah]
#
#                                             polarity
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 3  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  {'neg': 0.0, 'neu': 0.577, 'pos': 0.423, 'comp...

# %%
#run this cell to transform the polarity dictionary into columns of the DataFrame
lyrics[['neg', 'neu', 'pos', 'compound']] = lyrics['polarity'].apply(pd.Series)
lyrics.drop('polarity', axis=1)
# Out:
#                        album_name                  track_title  track_n  \
# 0     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 1     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 2     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 3     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# 4     Fearless (Taylor’s Version)  Fearless (Taylor’s Version)        1
# ...                           ...                          ...      ...
# 8353           Speak Now (Deluxe)                     Superman       17
# 8354           Speak Now (Deluxe)                     Superman       17
# 8355           Speak Now (Deluxe)                     Superman       17
# 8356           Speak Now (Deluxe)                     Superman       17
# 8357           Speak Now (Deluxe)                     Superman       17
#
#                                                   lyric  line  year  \
# 0                       There's something 'bout the way     1  2008
# 1                The street looks when it's just rained     2  2008
# 2     There's a glow off the pavement, you walk me t...     3  2008
# 3     And you know I wanna ask you to dance right there     4  2008
# 4                In the middle of the parking lot, yeah     5  2008
# ...                                                 ...   ...   ...
# 8353                   I'll be right here on the ground    51  2010
# 8354                            When you come back down    52  2010
# 8355                             La, la, la, la, la, la    53  2010
# 8356                             La, la, la, la, la, la    54  2010
# 8357                            When you come back down    55  2010
#
#                         clean_lyric  midnight_count  night_reg  day_reg  \
# 0                   theres bout way               0          0        0
# 1          street looks just rained               0          0        0
# 2     theres glow pavement walk car               0          0        0
# 3        know wanna ask dance right               0          0        0
# 4           middle parking lot yeah               0          0        0
# ...                             ...             ...        ...      ...
# 8353               ill right ground               0          0        0
# 8354                           come               0          0        0
# 8355              la la la la la la               0          0        0
# 8356              la la la la la la               0          0        0
# 8357                           come               0          0        0
#
#       time_reg                           lyrics_tok    neg    neu    pos  \
# 0            0                  [theres, bout, way]  0.000  1.000  0.000
# 1            0        [street, looks, just, rained]  0.000  1.000  0.000
# 2            0  [theres, glow, pavement, walk, car]  0.000  1.000  0.000
# 3            0     [know, wanna, ask, dance, right]  0.000  1.000  0.000
# 4            0         [middle, parking, lot, yeah]  0.000  0.577  0.423
# ...        ...                                  ...    ...    ...    ...
# 8353         0                 [ill, right, ground]  0.583  0.417  0.000
# 8354         0                               [come]  0.000  1.000  0.000
# 8355         0             [la, la, la, la, la, la]  0.000  1.000  0.000
# 8356         0             [la, la, la, la, la, la]  0.000  1.000  0.000
# 8357         0                               [come]  0.000  1.000  0.000
#
#       compound
# 0       0.0000
# 1       0.0000
# 2       0.0000
# 3       0.0000
# 4       0.2960
# ...        ...
# 8353   -0.4215
# 8354    0.0000
# 8355    0.0000
# 8356    0.0000
# 8357    0.0000
#
# [8358 rows x 16 columns]

# %% [markdown]
# ### 12. Corpus Sentiment Analysis
#
# Now that we have sentiment for all of her lyrics, let's learn more about her overall sentiment, as well as how that has change throughout her career.
# * Use the pos, neg, and compound columns to calculate the overall sentiment of her entire collection, and print the result.
# * Use the groupby function and matplotlib to visualize the overall sentiment of her albums over time

# %%
#calculate overall sentiment for pos, neg, sentiment

lyrics_sentimental = lyrics.loc[:,['neg', "pos", 'neu', 'compound','year']]

lyrics_sentimental = lyrics_sentimental.groupby('year').mean()
lyrics_sentimental.head()

#print the overall sentiments
# Out:
#            neg       pos       neu  compound
# year
# 2006  0.084240  0.180773  0.712007  0.071298
# 2008  0.095803  0.174611  0.718474  0.075683
# 2010  0.110369  0.171033  0.709061  0.038232
# 2012  0.089735  0.190717  0.699025  0.082568
# 2014  0.130679  0.200087  0.661280  0.068129

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    Overall Taylor Swift's lyrics are mostly positive!
# </details>

# %%
#create a new DataFrame using the groupby method for the album_year
#visualize sentiment over time 

plt.plot(lyrics_sentimental.index.astype(int), lyrics_sentimental.neg, label="negative")
plt.plot(lyrics_sentimental.index.astype(int), lyrics_sentimental.pos,label="pos")
plt.plot(lyrics_sentimental.index.astype(int), lyrics_sentimental.neu,label="neu")
plt.legend()

# plt.plot(lyrics_sentimental.index.astype(int), lyrics_sentimental.neg)

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
#    Her degree of positivity has really fluctuated over time. Her 2020 album was by far the least positive, though all of her albums are actually positive.
# </details>

# %% [markdown]
# ### 13. Day or Night? Positive or Negative
# Finally the big reveal. Does Taylor Swift write more positively about day or night?
# * Create two DataFrames: one for all the lyrics that mention night and one for all the lyrics that mention day.
# * Check that each DataFrame has the right number of values with the `len()` function
# * Calculate the sentiment for both night and day using the compound value and print them.

# %%
#create a DataFrame filtered for only night mentions

night_mentions = lyrics[lyrics.night_reg > 0]
#create a DataFrame filtered for only day mentions

day_mentions = lyrics[lyrics.day_reg > 0]
#print the length of the night and day DataFrames

print(len(night_mentions))
print(len(day_mentions))
# Out:
# 240
# 363

# %%
#calculate the sentiment of each day and night DataFrame from the compound values

# print(night_mentions.compound.mean())
#print the results

print(night_mentions.compound.mean())
print(day_mentions.compound.mean())
# Out:
# 0.07188583333333334
# 0.07243939393939396

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover in this step? Toggle to check!</i></summary>
#
# She's still overall more positive in her sentiment about day than night!
#
# You have the tools to explore if that sentiment has changed over time, or if her feelings towards night have grown more positive or negative over time. And of course, we would love to see your analysis of her new album, Midnight. Have her feelings changed?
#
# Share your findings in the Codecademy forums!
# </details>
